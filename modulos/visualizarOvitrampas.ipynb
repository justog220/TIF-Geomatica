# %%
import folium
import pandas as pd

# Load the data from the CSV file
data = pd.read_csv('data/posiciones_ovitrampas2.csv')

# Create a map centered on the first data point
map = folium.Map(location=[data['lat'].iloc[0], data['long'].iloc[0]], zoom_start=14, control_scale=True)


# Add markers for each data point
for index, row in data.iterrows():
	fecha = row['fecha']  # Color verde por defecto si no hay mapeo
	folium.Marker([row['lat'], row['long']]).add_to(map)

# Display the map
print(map.crs)
map
# Out:
# EPSG3857
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e36194c22999a1f8a66e3601788cbd53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e36194c22999a1f8a66e3601788cbd53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e36194c22999a1f8a66e3601788cbd53 = L.map(
#                 &quot;map_e36194c22999a1f8a66e3601788cbd53&quot;,
#                 {
#                     center: [-31.82822, -60.51399],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#
#
#
#             var tile_layer_5c40018564209b4aa9c2e8eb2586a319 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5c40018564209b4aa9c2e8eb2586a319.addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_6e4f7a4d3c126ed0b6cbd1072edfd9f5 = L.marker(
#                 [-31.82822, -60.51399],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_4d174617a4421349b2395487e64c1ceb = L.marker(
#                 [-31.82881, -60.51573],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_8898a7d44c0905e52abbdfb66e2a0fde = L.marker(
#                 [-31.82815, -60.51523],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_05be5225ed821c09e474dd2b2f6367e4 = L.marker(
#                 [-31.82795, -60.51634],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_4a2a6de981f8755b249e10355227406d = L.marker(
#                 [-31.82686, -60.51618],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_290a483b7dee83c234c9153abfbebfed = L.marker(
#                 [-31.82731, -60.51542],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_d8890ede75b5e8d5c3026b80406bc1e4 = L.marker(
#                 [-31.82643, -60.51484],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_1a914a37b4136506e2e916ce8ed42f83 = L.marker(
#                 [-31.82541, -60.51482],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_805b777f072dbae08b1d11274c5d4635 = L.marker(
#                 [-31.82497, -60.51399],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_b7fe97f4a66eb9bbe6ddc96fc3ff6047 = L.marker(
#                 [-31.82674, -60.51413],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_802b058d39572ecf07806e76db9f4538 = L.marker(
#                 [-31.82544, -60.51574],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_97e483dab8db370377039d330879834c = L.marker(
#                 [-31.82448, -60.51537],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_f18f3e6568128fb54abc96d71e56859e = L.marker(
#                 [-31.8257321, -60.5189836],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_81a6df6ed24894780c0603e032949b63 = L.marker(
#                 [-31.82226, -60.5131282],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_fb5eca6a4d115c34c36f0a9e4fdbdef0 = L.marker(
#                 [-31.825494, -60.5148855],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_37cf84a976ede4709c8cfe43fe5c7f7b = L.marker(
#                 [-31.8275059, -60.5151731],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_db533ac3d526e9deb204b483455cb69a = L.marker(
#                 [-31.8230592, -60.5147431],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_760e795c1402a744983ffa381230405b = L.marker(
#                 [-31.8216656, -60.5185606],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_376630f52ab31afc231acffad0d1a781 = L.marker(
#                 [-31.8217173, -60.518386],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_a6b52cee269adafdbae54d11023e01ca = L.marker(
#                 [-31.823242, -60.51899],
#                 {}
#             ).addTo(map_e36194c22999a1f8a66e3601788cbd53);
#
#
#             var marker_79e4b38faed44547b920c4

# %%
import folium
import pandas as pd

# Load the data from the CSV file
data = pd.read_csv('data/posiciones_ovitrampas2.csv')

# Create a map centered on the first data point
map = folium.Map(location=[data['lat'].iloc[0], data['long'].iloc[0]], zoom_start=14, control_scale=True, crs='EPSG32620')

# Add markers for each data point
for index, row in data.iterrows():
    fecha = row['fecha']  # Asumiendo que usarás 'fecha' más adelante
    folium.Marker([row['lat'], row['long']]).add_to(map)

# Display the map
print(map.crs)
map
# Out:
# EPSG32620
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9f13159c3c0264a056a22e721d4d951 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9f13159c3c0264a056a22e721d4d951&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9f13159c3c0264a056a22e721d4d951 = L.map(
#                 &quot;map_d9f13159c3c0264a056a22e721d4d951&quot;,
#                 {
#                     center: [-31.82822, -60.51399],
#                     crs: L.CRS.EPSG32620,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#
#
#
#             var tile_layer_9914a7757709dc7aa7e7982c5e89268b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9914a7757709dc7aa7e7982c5e89268b.addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_331ef069daa70e9a5dcb001b2c3a211f = L.marker(
#                 [-31.82822, -60.51399],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_69d1d85c7d01d520410316398204c5a5 = L.marker(
#                 [-31.82881, -60.51573],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_a28f0a7a9c6f664c931a24209aaf6c54 = L.marker(
#                 [-31.82815, -60.51523],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_7bb389eed07622adb4a61fea082dfdc5 = L.marker(
#                 [-31.82795, -60.51634],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_729ceaa384b27f995e783abfbe1fa33f = L.marker(
#                 [-31.82686, -60.51618],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_af7fa24035468d7a4078811b3f894e7a = L.marker(
#                 [-31.82731, -60.51542],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_649b868c6d982043e726d4d34b220410 = L.marker(
#                 [-31.82643, -60.51484],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_b0227edba6a8dc2773c90b65a336b0b5 = L.marker(
#                 [-31.82541, -60.51482],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_c4f71c09a37ec8fa9f290e129a4340cc = L.marker(
#                 [-31.82497, -60.51399],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_2427cabeececd8af98e1b33720c23a1b = L.marker(
#                 [-31.82674, -60.51413],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_6d1390c807908e5bb5db541cbb55f438 = L.marker(
#                 [-31.82544, -60.51574],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_5bf249bc10e81b78851e8eecee2f4c3a = L.marker(
#                 [-31.82448, -60.51537],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_3f73710741ad84c8b6c8acbf2fc40260 = L.marker(
#                 [-31.8257321, -60.5189836],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_db07d3484947180bc404d1f5a2932375 = L.marker(
#                 [-31.82226, -60.5131282],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_ecd72905e86526daba5f6a62849fa37b = L.marker(
#                 [-31.825494, -60.5148855],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_8454d6b0ca40567d6295c5890a237874 = L.marker(
#                 [-31.8275059, -60.5151731],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_e0feb04d754dd06f49f5cfa9e7bf717f = L.marker(
#                 [-31.8230592, -60.5147431],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_4c461906fa9e30218e3752a1d066edc3 = L.marker(
#                 [-31.8216656, -60.5185606],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_7732e90630ee2e4eb925d6eefa34e79a = L.marker(
#                 [-31.8217173, -60.518386],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_98dee7a7cca1011410a5d4c7fd48b904 = L.marker(
#                 [-31.823242, -60.51899],
#                 {}
#             ).addTo(map_d9f13159c3c0264a056a22e721d4d951);
#
#
#             var marker_16a9cc407c8985376642f

# %%
import io
from PIL import Image

img_data = map._to_png(5)
img = Image.open(io.BytesIO(img_data))
img.save('ovitrampas.png')
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# Cell In[2], line 4
#       1 import io
#       2 from PIL import Image
# ----> 4 img_data = map._to_png(5)
#       5 img = Image.open(io.BytesIO(img_data))
#       6 img.save('ovitrampas.png')
#
# File ~/.local/lib/python3.10/site-packages/folium/folium.py:359, in Map._to_png(self, delay, driver)
#     357     options = webdriver.firefox.options.Options()
#     358     options.add_argument("--headless")
# --> 359     driver = webdriver.Firefox(options=options)
#     361 html = self.get_root().render()
#     362 with temp_html_filepath(html) as fname:
#     363     # We need the tempfile to avoid JS security issues.
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/firefox/webdriver.py:69, in WebDriver.__init__(self, options, service, keep_alive)
#      62 executor = FirefoxRemoteConnection(
#      63     remote_server_addr=self.service.service_url,
#      64     keep_alive=keep_alive,
#      65     ignore_proxy=options._ignore_local_proxy,
#      66 )
#      68 try:
# ---> 69     super().__init__(command_executor=executor, options=options)
#      70 except Exception:
#      71     self.quit()
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:208, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options)
#     206 self._authenticator_id = None
#     207 self.start_client()
# --> 208 self.start_session(capabilities)
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:292, in WebDriver.start_session(self, capabilities)
#     285 """Creates a new session with the desired capabilities.
#     286
#     287 :Args:
#     288  - capabilities - a capabilities dict to start the session with.
#     289 """
#     291 caps = _create_caps(capabilities)
# --> 292 response = self.execute(Command.NEW_SESSION, caps)["value"]
#     293 self.session_id = response.get("sessionId")
#     294 self.caps = response.get("capabilities")
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# InvalidArgumentException: Message: binary is not a Firefox executable

# %%
import pandas as pd
import folium
import json

# Load the data from the CSV file
data = pd.read_csv('data/posiciones_ovitrampas2.csv')

# Calcular las coordenadas mínimas y máximas de latitud y longitud
min_lat = data['lat'].min()
max_lat = data['lat'].max()
min_lon = data['long'].min()
max_lon = data['long'].max()

# Calcular el centro del ROI
center_lat = (min_lat + max_lat) / 2
center_lon = (min_lon + max_lon) / 2

# Calcular la diferencia entre las coordenadas máximas y mínimas
diff_lat = max_lat - min_lat
diff_lon = max_lon - min_lon

# Agregar un margen de 2 km a la diferencia
margin = 0.02  # 2 km en grados
diff_lat += margin
diff_lon += margin

# Calcular la mitad de la diferencia ajustada
half_diff_lat = diff_lat / 2
half_diff_lon = diff_lon / 2

if half_diff_lat > half_diff_lon:
	half_diff_lon = half_diff_lat
else:
	half_diff_lat = half_diff_lon

print(half_diff_lat == half_diff_lon)

# Calcular las coordenadas del ROI
roi_lat = [center_lat - half_diff_lat, center_lat + half_diff_lat]
roi_lon = [center_lon - half_diff_lon, center_lon + half_diff_lon]

# Crear un mapa centrado en el centro del ROI
map = folium.Map(location=[center_lat, center_lon], zoom_start=14)

# Agregar un marcador para cada punto en el DataFrame
for index, row in data.iterrows():
	folium.Marker([row['lat'], row['long']]).add_to(map)

# Agregar un rectángulo que representa el ROI

print(f"{roi_lat, roi_lon}")

folium.Rectangle(bounds=[[roi_lat[0], roi_lon[0]], [roi_lat[1], roi_lon[1]]], color='red', fill=False).add_to(map)

# Mostrar el mapa
map
# Out:
# True
# ([-31.85280432, -31.810500800000003], [-60.539312540000005, -60.49700902])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb116d4e9af40f07ec5306c1556ac2f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb116d4e9af40f07ec5306c1556ac2f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb116d4e9af40f07ec5306c1556ac2f9 = L.map(
#                 &quot;map_eb116d4e9af40f07ec5306c1556ac2f9&quot;,
#                 {
#                     center: [-31.831652560000002, -60.51816078],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f88dbbc288bb293860696b598a4d9124 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f88dbbc288bb293860696b598a4d9124.addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_dad13470ccddb5a653647a82f1a6e527 = L.marker(
#                 [-31.82822, -60.51399],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_93c850ec392ed013726c51593fd43185 = L.marker(
#                 [-31.82881, -60.51573],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_a2612930877e8e0851944423810e8136 = L.marker(
#                 [-31.82815, -60.51523],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_066948ad8b71a09d069fdd620cac9675 = L.marker(
#                 [-31.82795, -60.51634],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_1f4d089876c6945452920189e853775d = L.marker(
#                 [-31.82686, -60.51618],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_88d7c09786c1e77d45688db10d229e39 = L.marker(
#                 [-31.82731, -60.51542],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_e96384553d48b142af1413069ef5f233 = L.marker(
#                 [-31.82643, -60.51484],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_5915edade8ca89b2eba2df1d518e8a51 = L.marker(
#                 [-31.82541, -60.51482],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_25e1bd4213ca9b8d191bb6aa9af1d8ae = L.marker(
#                 [-31.82497, -60.51399],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_1b73e2f3bcfaeb5d77fb679abd21c12a = L.marker(
#                 [-31.82674, -60.51413],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_e07cfdc6dd6a08fdeb4a2ebbcb9ab7d9 = L.marker(
#                 [-31.82544, -60.51574],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_71ca7f5b44fa657d2e2c7f68098e1f74 = L.marker(
#                 [-31.82448, -60.51537],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_dfbfec8ca8ac62ec8550a7fd1639feff = L.marker(
#                 [-31.8257321, -60.5189836],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_42887d1bcc3d86b90897d7c3a86f3811 = L.marker(
#                 [-31.82226, -60.5131282],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_d481b797aa6fd8d657cb6a8c72dac626 = L.marker(
#                 [-31.825494, -60.5148855],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_9c52b528d1b74bc6a00d82efee200f12 = L.marker(
#                 [-31.8275059, -60.5151731],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_0e204f0e2c329cb752226f27d6fb177f = L.marker(
#                 [-31.8230592, -60.5147431],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_e00d7fb24d357e5664347d2b098b4bef = L.marker(
#                 [-31.8216656, -60.5185606],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_3a96c18af64f00854f359388ee76f581 = L.marker(
#                 [-31.8217173, -60.518386],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_3d9f08e918f74f887d8b3abcf7bba69e = L.marker(
#                 [-31.823242, -60.51899],
#                 {}
#             ).addTo(map_eb116d4e9af40f07ec5306c1556ac2f9);
#
#
#             var marker_2a5efcc32aeaf9e23671800156714056 = L.marker(
#                 [-31.8260724, -60.52182

# %%
import io
from PIL import Image

img_data = map._to_png(5)
img = Image.open(io.BytesIO(img_data))
img.save('ovitrampasConROI.png')
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# Cell In[4], line 4
#       1 import io
#       2 from PIL import Image
# ----> 4 img_data = map._to_png(5)
#       5 img = Image.open(io.BytesIO(img_data))
#       6 img.save('ovitrampasConROI.png')
#
# File ~/.local/lib/python3.10/site-packages/folium/folium.py:359, in Map._to_png(self, delay, driver)
#     357     options = webdriver.firefox.options.Options()
#     358     options.add_argument("--headless")
# --> 359     driver = webdriver.Firefox(options=options)
#     361 html = self.get_root().render()
#     362 with temp_html_filepath(html) as fname:
#     363     # We need the tempfile to avoid JS security issues.
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/firefox/webdriver.py:69, in WebDriver.__init__(self, options, service, keep_alive)
#      62 executor = FirefoxRemoteConnection(
#      63     remote_server_addr=self.service.service_url,
#      64     keep_alive=keep_alive,
#      65     ignore_proxy=options._ignore_local_proxy,
#      66 )
#      68 try:
# ---> 69     super().__init__(command_executor=executor, options=options)
#      70 except Exception:
#      71     self.quit()
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:208, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options)
#     206 self._authenticator_id = None
#     207 self.start_client()
# --> 208 self.start_session(capabilities)
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:292, in WebDriver.start_session(self, capabilities)
#     285 """Creates a new session with the desired capabilities.
#     286
#     287 :Args:
#     288  - capabilities - a capabilities dict to start the session with.
#     289 """
#     291 caps = _create_caps(capabilities)
# --> 292 response = self.execute(Command.NEW_SESSION, caps)["value"]
#     293 self.session_id = response.get("sessionId")
#     294 self.caps = response.get("capabilities")
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# InvalidArgumentException: Message: binary is not a Firefox executable
